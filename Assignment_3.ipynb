# %% [markdown]
# # Assignment 3

# %% [markdown]
# Theoritical Questions

# %% [markdown]
# Q.1 What is the difference between a function and a method in Python?
# - Function (Theoretical Definition)
# A function in Python is a self-contained block of reusable code that performs a specific task. It is defined using the def keyword and can be invoked independently. Functions can accept input arguments and return output values. They are part of Python's procedural programming paradigm and do not inherently operate on any object unless explicitly passed.
#
#  Method (Theoretical Definition)
# A method is a function that is associated with an object. In Python, methods are defined within a class and are meant to operate on instances of that class (objects). They implicitly take the instance (self) as their first argument and are part of Python's object-oriented programming paradigm. Methods are invoked on objects and can access and modify the object’s internal state.
#
# Example of Function

# %%
def add(a, b):
    return a + b

# Calling the function
result = add(3, 5)
print(result)  # Output: 8

# %% [markdown]
# Example of a Method

# %%
class Calculator:
    def add(self, a, b):
        return a + b

# Creating an object of the class
calc = Calculator()

# Calling the method
result = calc.add(3, 5)
print(result)  # Output: 8

# %% [markdown]
# Q.2 . Explain the concept of function arguments and parameters in Python.
# - 📘 Function Arguments and Parameters in Python
# In Python, parameters and arguments are used in functions to pass and receive data.
#
#  🔹 Parameters
# Parameters are placeholders used when defining a function.
#
#  They act as variable names that will receive values (arguments) when the function is called.
#
#  Example:

# %%
def greet(name):  # 'name' is a parameter
    print(f"Hello, {name}!")

# %% [markdown]
#   🔹 Arguments
#   Arguments are the actual values passed to the function when it is called.
#
# They are assigned to the parameters of the function.
#
# Example:

# %%
greet("Alice")  # "Alice" is the argument

# %% [markdown]
# Q.3  What are the different ways to define and call a function in Python?
# - In Python, functions can be defined and called in several ways:
#
#  1. Standard Function:
#
#  - Defined using def with fixed parameters.
#
#  - Called by passing arguments in order.
#
#  Example;

# %%
def add(a, b): return a + b

# %% [markdown]
# - 2. Default Arguments:
#
# Parameters have default values.
#
# Useful when some arguments are optional.
#
# Example;

# %%
def greet(name="Guest")

# %% [markdown]
# - 3. Keyword Arguments:
#
#  Call function using parameter names.
#
#  Example;

# %%
greet(name="Alice")

# %% [markdown]
# - 4. Variable-Length Arguments:
#
#  *args for multiple positional arguments.
#
#  **kwargs for multiple keyword arguments.
#
# Example;

# %%
def show(*args, **kwargs)

# %% [markdown]
# - 5. Lambda Functions:
#
#  Anonymous, one-line functions.
#
# Example:

# %%
square = lambda x: x*x

# %% [markdown]
# Q.4  What is the purpose of the `return` statement in a Python function?
# - The return statement in a Python function is used to send a result (value or object) back to the caller of the function. It terminates the function execution and passes the specified value to the point where the function was called.
#
#  - It allows functions to produce output.
#
#  - A function can return any data type: number, string, list, object, etc.
#
#  - If no return is used, the function returns None by default.
#
# Example;

# %%
def square(num):
    return num * num

result = square(4)
print(result)  # Output: 16

# %% [markdown]
# Q.5  What are iterators in Python and how do they differ from iterables?
# - Iterable (What can be looped over)
# An iterable is any Python object that can be looped over (i.e., used in a for loop).
# It implements the __iter__() method, which returns an iterator.
#
#  Examples of iterables:
#
#  - Lists, tuples, strings, dictionaries, sets.
#
# - Iterator (The tool that does the looping)
#
#  An iterator is an object that represents a stream of data, and it produces items one at a time using the next() function.
# It implements both:
#
# __iter__() — returns itself.
#
# __next__() — returns the next value, and raises StopIteration when done.

# %%
# Iterable
numbers = [1, 2, 3]         # This is an iterable

# Creating an iterator from iterable
it = iter(numbers)          # This is an iterator

print(next(it))  # Output: 1
print(next(it))  # Output: 2
print(next(it))  # Output: 3

# %% [markdown]
# Q.6 Explain the concept of generators in Python and how they are defined.
# - 🔹 Concept of Generators:
#
#  A generator is a special type of function in Python that returns an iterator and allows you to iterate over a sequence of values lazily (one value at a time, only when needed).
# Instead of using return, it uses the yield keyword to produce a value and pause the function’s execution, resuming from that point on the next call.
#
# - 🔹 Why Use Generators?
#
#  Memory-efficient: Does not store the entire sequence in memory.
#
#  - Useful for large or infinite data streams.
#
#  - Faster startup time than building entire lists.
#
# - 🔹 How to Define a Generator:
#
#  Generators are defined like normal functions but use yield instead of return.
#
#  Example ;

# %%
def count_up_to(n):
    count = 1
    while count <= n:
        yield count
        count += 1

gen = count_up_to(3)

for num in gen:
    print(num)

# %% [markdown]
# Q.7  What are the advantages of using generators over regular functions?
# - Generators provide several key advantages compared to regular functions that return complete data structures:
#
#  1.Memory Efficiency:
#
#  Generators produce items one at a time and only when requested, so they do not store the entire sequence in memory. This makes them ideal for handling large datasets or infinite sequences.
#
#  2.Lazy Evaluation:
#
#  Values are generated on demand rather than computed all at once. This improves performance and reduces initial loading time.
#
#  Ability to Represent Infinite Sequences:
# Because generators yield items one by one, they can generate infinite data streams without running out of memory.
#
#  Improved Performance:
# By avoiding the creation of full lists, generators can be faster and more efficient in iterations over large data.
#
#  Simplified Code:
# Using yield allows writing cleaner, more readable code for producing sequences compared to managing and returning lists manually.

# %% [markdown]
# Q.8 What is a lambda function in Python and when is it typically used?
# - A lambda function is a small, anonymous function defined using the lambda keyword.
# It can take any number of arguments but contains only a single expression whose result is implicitly returned.
#
# - 🔹 Syntax:

# %%
lambda arguments: expression

# %% [markdown]
# Example ;

# %%
# Regular function to square a number
def square(x):
    return x * x

# Equivalent lambda function
square_lambda = lambda x: x * x

print(square_lambda(5))  # Output: 25

# %% [markdown]
# Q.9  Explain the purpose and usage of the `map()` function in Python.
# - ### Purpose and Usage of the `map()` Function in Python (Theoretical)
#
#  The `map()` function in Python is used to apply a specified function to **each item** of one or more iterables (such as lists or tuples) and returns an iterator that yields the results. It enables functional-style programming by allowing transformation or processing of data sequences without explicit loops.
#
#  `map()` takes a function and one or more iterables as arguments. The function is applied to the items of the iterable(s) in parallel, and the results are produced lazily as a map object. This map object can be converted to other iterable types like lists or tuples if needed.
#
#  This function is useful for concise, readable, and efficient data processing tasks, especially when combined with anonymous functions (lambdas).
#
#  Example ;

# %%
numbers = [1, 2, 3, 4]
squared = map(lambda x: x * x, numbers)
print(list(squared))  # Output: [1, 4, 9, 16]

# %% [markdown]
# Q.10 What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# - ### Difference Between `map()`, `filter()`, and `reduce()` Functions (Theory)
#
# * **`map()`** applies a given function to every item of one or more iterables and returns an iterator with the transformed results. It is used to **transform** data.
#
# * **`filter()`** applies a function that returns a boolean value (True or False) to each item of an iterable and returns an iterator containing only those items for which the function returns True. It is used to **select** data based on a condition.
#
# * **`reduce()`** (from the `functools` module) applies a binary function cumulatively to the items of an iterable, reducing the iterable to a single accumulated value. It is used to **aggregate** data into one result.
#
# In summary, `map()` transforms each item, `filter()` selects items, and `reduce()` combines items to produce a single output.

# %% [markdown]
# Q.11 Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];

# %% [markdown]
# ![answer.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# #Practical Questions

# %% [markdown]
# Q.1 . Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

# %%
def sum_even_numbers(numbers):
    total = 0
    for num in numbers:
        if num % 2 == 0:
            total += num
    return total

# Example usage:
nums = [1, 2, 3, 4, 5, 6]
print(sum_even_numbers(nums))
# Out:
# 12

# %% [markdown]
# Q.2  Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(s):
    return s[::-1]

# Example usage:
input_str = "hello"
reversed_str = reverse_string(input_str)
print(reversed_str)
# Out:
# olleh

# %% [markdown]
# Q.3  Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.

# %%
def square_numbers(numbers):
    return [x ** 2 for x in numbers]

# Example usage:
input_list = [1, 2, 3, 4, 5]
squared_list = square_numbers(input_list)
print(squared_list)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# Q.4  Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(n):
    if n < 2 or n > 200:
        return False  # Outside the valid range
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

# Example usage:
for num in range(1, 201):
    if is_prime(num):
        print(f"{num} is a prime number.")
# Out:
# 2 is a prime number.
# 3 is a prime number.
# 5 is a prime number.
# 7 is a prime number.
# 11 is a prime number.
# 13 is a prime number.
# 17 is a prime number.
# 19 is a prime number.
# 23 is a prime number.
# 29 is a prime number.
# 31 is a prime number.
# 37 is a prime number.
# 41 is a prime number.
# 43 is a prime number.
# 47 is a prime number.
# 53 is a prime number.
# 59 is a prime number.
# 61 is a prime number.
# 67 is a prime number.
# 71 is a prime number.
# 73 is a prime number.
# 79 is a prime number.
# 83 is a prime number.
# 89 is a prime number.
# 97 is a prime number.
# 101 is a prime number.
# 103 is a prime number.
# 107 is a prime number.
# 109 is a prime number.
# 113 is a prime number.
# 127 is a prime number.
# 131 is a prime number.
# 137 is a prime number.
# 139 is a prime number.
# 149 is a prime number.
# 151 is a prime number.
# 157 is a prime number.
# 163 is a prime number.
# 167 is a prime number.
# 173 is a prime number.
# 179 is a prime number.
# ...

# %% [markdown]
# Q.5  Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

# %%
class FibonacciIterator:
    def __init__(self, max_terms):
        self.max_terms = max_terms
        self.count = 0
        self.a = 0
        self.b = 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.max_terms:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return 0
        elif self.count == 1:
            self.count += 1
            return 1
        else:
            self.count += 1
            self.a, self.b = self.b, self.a + self.b
            return self.a

# Example usage:
fib = FibonacciIterator(10)
for num in fib:
    print(num)
# Out:
# 0
# 1
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %% [markdown]
# Q.6  Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(max_exponent):
    for exp in range(max_exponent + 1):
        yield 2 ** exp

# Example usage:
for power in powers_of_two(5):
    print(power)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %% [markdown]
# Q.7  Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file_line_by_line(file_path):
    try:
        with open(file_path, 'r') as file:
            for line in file:
                yield line.rstrip('\n')
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
for line in read_file_line_by_line('example.txt'):
    print(line)
# Out:
# Error: File 'example.txt' not found.

# %% [markdown]
# Q.8 . Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
# List of tuples
data = [(1, 3), (4, 1), (2, 2), (5, 0)]

# Sort by the second element of each tuple
sorted_data = sorted(data, key=lambda x: x[1])

print(sorted_data)
# Out:
# [(5, 0), (4, 1), (2, 2), (1, 3)]

# %% [markdown]
# Q.9 Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
# List of temperatures in Celsius
celsius_temps = [0, 20, 37, 100]

# Conversion formula: F = C * 9/5 + 32
fahrenheit_temps = list(map(lambda c: c * 9/5 + 32, celsius_temps))

print("Celsius:", celsius_temps)
print("Fahrenheit:", fahrenheit_temps)
# Out:
# Celsius: [0, 20, 37, 100]
# Fahrenheit: [32.0, 68.0, 98.6, 212.0]

# %% [markdown]
# Q.10 Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
def remove_vowels(input_str):
    vowels = 'aeiouAEIOU'
    return ''.join(filter(lambda char: char not in vowels, input_str))

# Example usage
text = "Hello, World!"
result = remove_vowels(text)

print("Original:", text)
print("Without vowels:", result)
# Out:
# Original: Hello, World!
# Without vowels: Hll, Wrld!

# %% [markdown]
# Q.11  Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
# ![Screenshot 2025-05-22 215731.png](data:image/png;base64,...)
#
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map.

# %%
# Sample data based on the image
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

# Using map and lambda to compute the required list of tuples
result = list(map(lambda order: (
    order[0],
    round(order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0), 2)
), orders))

print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85), (88112, 84.97)]
